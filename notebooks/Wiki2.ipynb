# %%
dfconstructors = spark.sql("SELECT * FROM F1.constructors")
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 8, Finished, Available, Finished)

# %%
dfconstructorswithimages2= spark.sql("SELECT * FROM F1.constructorswithimages2")
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 13, Finished, Available, Finished)

# %%
display(dfconstructorswithimages2)
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 14, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5ccba89f-b053-4239-b304-6053f060c477)

# %%
import pandas as pd
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 15, Finished, Available, Finished)

# %%
dfconstructorswithimages2= pd.read_csv('abfss://883c397f-6409-4489-becd-c2232efd4711@onelake.dfs.fabric.microsoft.com/25d8e49f-0659-423b-842c-d162a87313d2/Files/constructorswithimages2.csv',delimiter=';')
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 10, Finished, Available, Finished)

# %%
dfconstructorswithimages2.head()
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 16, Finished, Available, Finished)
# Row(id=85, constructorId=87, constructorRef='cooper', name='Cooper', nationality='British', url='http://en.wikipedia.org/wiki/Cooper_Car_Company', url2='https://en.wikipedia.org/wiki/Cooper_Car_Company', image_urls='https://upload.wikimedia.org/wikipedia/commons/6/62/Cooper_Mk_IV_of_Garry_Simkin.JPG')

# %%
display(dfconstructorswithimages2['url2'])
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 18, Finished, Available, Finished)
# Column<'url2'>

# %%
import pyspark.pandas as ps
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 20, Finished, Available, Finished)

# %%
dfconstructorspanda= dfconstructorswithimages2.pandas_api()
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 21, Finished, Available, Finished)

# %%
urlsconstructors= dfconstructorspanda['url2']
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 22, Finished, Available, Finished)

# %%
urlsconstructors= urlsconstructors.to_numpy()
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 32, Finished, Available, Finished)
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/utils.py:1016: PandasAPIOnSparkAdviceWarning: `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
# !pip install wikipedia
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 24, Finished, Available, Finished)
# ...
# done
# ...
# done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=34b8add3ab07a7a95236da309630e01cb071901718c079ede46dd995889f58fa
#   Stored in directory: /home/trusted-service-user/.cache/pip/wheels/8f/ab/cb/45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# ...

# %%
for i in urlsconstructors:
    print(i[30:])
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 33, Finished, Available, Finished)
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# Cooper_Car_Company
# McLaren_Automotive
# Williams_Grand_Prix_Engineering
# Scuderia_Toro_Rosso
# Sauber_Motorsport
# Prost_Grand_Prix
# MasterCard_Lola
# Ligier
# Simtek
# Team_Lotus
# Dallara
# Automobiles_Gonfaronnaises_Sportives
# Modena_(racing_team)
# RAM_Racing
# Shadow_Racing_Cars
# Merzario
# Kauhsen
# Rebaque
# Hesketh_Racing
# Kojima_Engineering
# De_Tomaso
# LDS_(automobile)
# Scirocco-Powell
# Emeryson
# JBW
# Maserati
# Scarab_(constructor)
# Meskowski
# Kurtis_Kraft
# Vanwall
# Tec-Mec
# Bugatti
# Hersham_and_Walton_Motors
# Arzani-Volpini
# Simca
# BMW_in_Formula_One
# Eisenacher_Motorenwerk
# Alex_von_Falkenhausen_Motorenbau
# Frazer_Nash
# English_Racing_Automobiles
# ...

# %%
import wikipedia
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 36, Finished, Available, Finished)

# %%
urlsconstructors[15]
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 39, Finished, Available, Finished)
# 'https://en.wikipedia.org/wiki/Prost_Grand_Prix'

# %%
contador=0
for the_page in urlsconstructors[:15]:
    print(the_page)
    try:
        the_url = wikipedia.page(the_page[30:])
        print(the_url.images)
        indices = [i for i, s in enumerate(the_url.images) if 'logo' in s.lower()]
        print(indices)
    except:
        print("page not found")
        contador+=1
        continue
print(contador)
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 41, Finished, Available, Finished)
# https://en.wikipedia.org/wiki/Cooper_Car_Company
# ...

# %%
import wikipedia

# %%
image_urlsconstructors=[]
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 42, Finished, Available, Finished)

# %%
for the_page in urlsconstructors:
    try:
        the_url = wikipedia.page(the_page[30:])
        #indices = [i for i, s in enumerate(the_url.images) if 'logo' in s.lower()]
        #if len(indices)>0:
        #image_urlsconstructors.append(the_url.images[indices[0]])
        #else:
        image_urlsconstructors.append(the_url.images[0])            
    except:
        image_urlsconstructors.append("No image file")
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 43, Finished, Available, Finished)

# %%
image_urlsconstructors.count('No image file')
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 44, Finished, Available, Finished)
# 25

# %%
image_urlsconstructors
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 45, Finished, Available, Finished)
# ['https://upload.wikimedia.org/wikipedia/commons/9/93/1955_Cooper_Jaguar_T38_%2848914350423%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/93/1955_Cooper_Jaguar_T38_%2848914350423%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/93/1955_Cooper_Jaguar_T38_%2848914350423%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/93/1955_Cooper_Jaguar_T38_%2848914350423%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/93/1955_Cooper_Jaguar_T38_%2848914350423%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/93/1955_Cooper_Jaguar_T38_%2848914350423%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/93/1955_Cooper_Jaguar_T38_%2848914350423%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/93/1955_Cooper_Jaguar_T38_%2848914350423%29.jpg',
# ...

# %%
contador=0
for the_page in urlsconstructors:
    print(the_page)
    try:
        the_url = wikipedia.page(the_page[30:])
        print(the_url.images)
    except:
        print("page not found")
        contador+=1
        continue
print(contador)
# Out:
# StatementMeta(, 78675ca6-107b-44ef-8b95-76e84f1ea2ea, 34, Finished, Available, Finished)
# https://en.wikipedia.org/wiki/McLaren_Automotive
# ...

# %%
print("PROPORCION DE ESCUDERIAS SIN IMAGEN PRINCIPAL: ",image_urlsconstructors.count("No image file"),'/', len(image_urlsconstructors))
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 46, Finished, Available, Finished)
# PROPORCION DE ESCUDERIAS SIN IMAGEN PRINCIPAL:  25 / 212

# %%
dfconstructorspanda
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 47, Finished, Available, Finished)
#       id  constructorId        constructorRef                  name    nationality                                                                        url                                                                        url2                                                                                                                  image_urls
# 0     85             87                cooper                Cooper        British                            http://en.wikipedia.org/wiki/Cooper_Car_Company                            https://en.wikipedia.org/wiki/Cooper_Car_Company                                        https://upload.wikimedia.org/wikipedia/commons/6/62/Cooper_Mk_IV_of_Garry_Simkin.JPG
# ...

# %%
dfconstructorspanda['imurl'] = image_urlsconstructors
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 48, Finished, Available, Finished)

# %%
dfconstructorspanda
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 49, Finished, Available, Finished)
#       id  constructorId        constructorRef                  name    nationality                                                                        url                                                                        url2                                                                                                                  image_urls                                                                                                                                                                                                                               imurl
# ...

# %%
dfconstructors=dfconstructorspanda.to_spark()
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 50, Finished, Available, Finished)
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/utils.py:1016: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `to_spark`, the existing index is lost when converting to Spark DataFrame.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
display(dfconstructors)
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 51, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4bb50ae3-04a8-4f66-b04e-c1dc971dedfa)

# %%
dfconstructors.write.format("delta").saveAsTable("constructorswithimages3")
# Out:
# StatementMeta(, 86e2c2ad-b27c-40a3-8ef5-438903d19d86, 52, Finished, Available, Finished)
