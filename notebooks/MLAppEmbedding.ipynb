# %%
CreationQuery = """CREATE TABLE ExternalApps (
    AppId int,
    AppName varchar(255),
    AppUrl varchar(255),
    AppDescription varchar(255)
) ;
"""
https://f1raceintel.streamlit.app/
# Out:
# StatementMeta(, 8890dd8d-e76f-4f12-a256-4587272e9802, 3, Finished, Available, Finished)

# %%
creation = spark.sql(CreationQuery)
# Out:
# StatementMeta(, 8890dd8d-e76f-4f12-a256-4587272e9802, 4, Finished, Available, Finished)

# %%
InsertionQuery = """INSERT INTO ExternalApps
VALUES (1,'Prediccion de Posición de Pilotos por Carrera', 'https://raceintel-ejwmmk3kufqsfpzrgwv4z6.streamlit.app/','Streamlit Random Forest');
"""
insertion = spark.sql(InsertionQuery)
# Out:
# StatementMeta(, 8890dd8d-e76f-4f12-a256-4587272e9802, 5, Finished, Available, Finished)
